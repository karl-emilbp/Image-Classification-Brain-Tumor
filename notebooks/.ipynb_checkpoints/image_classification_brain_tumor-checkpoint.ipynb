# %% [markdown]
# # Image Classification - Brain Tumor.
# This notebook aims to detect brain tumors in MRI images.

# %%
# Import relevant packages.

import numpy as np
from tensorflow.keras import layers
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get data.
# Load data and split data in train, val, test datasets.

# %%
batch_size = 16
img_height = 256
img_width = 256

train_data_dir = "../data/train"
test_data_dir = "../data/test"

train = tf.keras.utils.image_dataset_from_directory(
    train_data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val = tf.keras.utils.image_dataset_from_directory(
    train_data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

test = tf.keras.utils.image_dataset_from_directory(
    test_data_dir,
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 232 files belonging to 2 classes.
# Using 186 files for training.
# Found 232 files belonging to 2 classes.
# Using 46 files for validation.
# Found 21 files belonging to 2 classes.

# %%
# Print Class labels.
class_names = train.class_names
print(class_names)
# Out:
# ['no', 'yes']

# %% [markdown]
# ### Visualize sample of images.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train.take(1):
    for i in range(3):
        ax = plt.subplot(1, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Apply data augmentation.
# Create layers for data augmentations: Flip and Rotation.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
])

# %% [markdown]
# ### Add prefetching and caching.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train = train.cache().prefetch(buffer_size=AUTOTUNE)
val = val.cache().prefetch(buffer_size=AUTOTUNE)
test = test.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Define Convolutional Neural Network model

# %%
# Convolutional Neural Network.

input_shape = (256, 256, 3)
num_classes = len(class_names)

model = tf.keras.Sequential([
    tf.keras.Input(shape=input_shape),
    tf.keras.layers.Rescaling(1./255),
    data_augmentation,
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# ...
# Total params: 3,706,178
# Trainable params: 3,706,178
# ...

# %%
# Compile model.

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model.compile(
    optimizer='adam',
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
    callbacks=[callback]
)

# %% [markdown]
# ### Train CNN model.

# %%
# Train CNN model on train dataset and validate on val dataset.

history = model.fit(
    train,
    validation_data=val,
    epochs=200
)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 12s 943ms/step - loss: 0.6994 - accuracy: 0.5753 - val_loss: 0.5437 - val_accuracy: 0.7391
# Epoch 2/200
# 12/12 [==============================] - 11s 900ms/step - loss: 0.5888 - accuracy: 0.7312 - val_loss: 0.5080 - val_accuracy: 0.7609
# Epoch 3/200
# 12/12 [==============================] - 11s 880ms/step - loss: 0.5310 - accuracy: 0.7634 - val_loss: 0.5976 - val_accuracy: 0.6957
# Epoch 4/200
# 12/12 [==============================] - 11s 931ms/step - loss: 0.5088 - accuracy: 0.7742 - val_loss: 0.5580 - val_accuracy: 0.7826
# Epoch 5/200
# 12/12 [==============================] - 11s 900ms/step - loss: 0.5062 - accuracy: 0.7742 - val_loss: 0.5522 - val_accuracy: 0.7826
# Epoch 6/200
# 12/12 [==============================] - 11s 893ms/step - loss: 0.4961 - accuracy: 0.7903 - val_loss: 0.5460 - val_accuracy: 0.7826
# Epoch 7/200
# ...

# %% [markdown]
# ### Visualize training and validation loss.

# %%
# Loss plot
plt.title('Avg Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

train_losses = [model_history[i].history['loss'] for i in range(len(model_history))]
val_losses = [model_history[i].history['val_loss'] for i in range(len(model_history))]

sum_train_loss = [sum(x) for x in zip(*train_losses)]
sum_val_loss = [sum(x) for x in zip(*val_losses)]

avg_train_loss = [x / len(model_history) for x in sum_train_loss]
avg_val_loss = [x / len(model_history) for x in sum_val_loss]

plt.plot(avg_train_loss, label="Train")
plt.plot(avg_val_loss, label="Validation")
plt.legend()
plt.show()

# %% [markdown]
# ### Visualize training and validation accuracy.

# %%
# Score (Accuracy) plot.
plt.title('Avg CNN Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

train_scores = [model_history[i].history['accuracy'] for i in range(len(model_history))]
val_scores = [model_history[i].history['val_accuracy'] for i in range(len(model_history))]

sum_train_scores = [sum(x) for x in zip(*train_scores)]
sum_val_scores = [sum(x) for x in zip(*val_scores)]

avg_train_scores = [x / len(model_history) for x in sum_train_scores]
avg_val_scores = [x / len(model_history) for x in sum_val_scores]

plt.plot(avg_train_scores, label="Train")
plt.plot(avg_val_scores, label="Validation")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate model on test dataset.

# %%
# Evaluate on test set.

results = model.evaluate(test, batch_size=batch_size)
print(f"Test loss and Test accuracy: {results}")
